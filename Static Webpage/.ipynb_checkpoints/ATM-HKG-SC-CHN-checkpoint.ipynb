# %%
#全部都是ATM

# %%
import requests
import re
import urllib.request, json
import pandas as pd

# %%
url = ("https://www.sc.com/hk/zh/data/atm-branch/v2/all-atms-branches.json")

# %%
web = requests.get(url)
data = json.loads(web.text)
#Method 2
#response = urllib.request.urlopen(url)
#data = json.loads(response.read())

# %%
data
# Out:
# {'locations': [{'address': {'addressLines': ['立坊自動櫃員機', '荃灣楊屋道118號立坊地下A舖'],
#     'city': '新界',
#     'latitude': '22.366554',
#     'longitude': '114.117808',
#     'placeId': '',
#     'postalCode': None},
#    'id': 225140,
#    'is-24-hours': True,
#    'name': '立坊自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港鰂魚涌英皇道683號嘉里中心2樓 (富嘉閣舖對面)'],
#     'city': '香港',
#     'latitude': '22.290585',
#     'longitude': '114.209748',
#     'placeId': '',
#     'postalCode': None},
#    'id': 171163,
#    'is-24-hours': True,
#    'name': '嘉里中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港九龍灣宏照道38號企業廣場五期Megabox3樓 (307號舖側)'],
#     'city': '九龍',
#     'latitude': '22.320141',
#     'longitude': '114.208468',
#     'placeId': '',
#     'postalCode': None},
#    'id': 170419,
#    'is-24-hours': True,
#    'name': 'MegaBox 自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['大嶼山東涌迎東邨迎喜樓'],
#     'city': None,
#     'latitude': '22.295719',
#     'longitude': '113.953446',
#     'placeId': '',
#     'postalCode': None},
#    'id': 88740,
#    'is-24-hours': False,
#    'name': '迎東邨流動分行自動櫃員機',
#    'regularHours': [{'closeDay': 4,
#      'closeTime': '11:00 AM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '04:00 PM',
#      'openDay': 4,
#      'openTime': '12:00 PM'}],
#    'services': ['hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['大嶼山東涌迎東邨迎喜樓'],
#     'city': None,
#     'latitude': '22.295719',
#     'longitude': '113.953446',
#     'placeId': '',
#     'postalCode': None},
#    'id': 88739,
#    'is-24-hours': False,
#    'name': '迎東邨- 渣打流動分行',
#    'regularHours': [{'closeDay': 4,
#      'closeTime': '11:00 AM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '04:00 PM',
#      'openDay': 4,
#      'openTime': '12:00 PM'}],
#    'services': ['personal-banking',
#     'counter-services',
#     'self-service-banking'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['branch']},
#   {'address': {'addressLines': ['九龍尖沙咀柯士甸道西3號香港西九龍站B2抵港大堂WEK B2-2號舖'],
#     'city': None,
#     'latitude': '22.303805',
#     'longitude': '114.165223',
#     'placeId': '',
#     'postalCode': None},
#    'id': 87733,
#    'is-24-hours': False,
#    'name': '西九龍站快捷理財中心',
#    'regularHours': [],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'digital-teller'],
#    'status': 'open',
#    'telephone': ['25410494'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['九龍尖沙咀柯士甸道西3號香港西九龍站B2抵港大堂WEK B2-2號舖'],
#     'city': '',
#     'latitude': '22.303805',
#     'longitude': '114.165223',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 87732,
#    'is-24-hours': True,
#    'name': '西九龍站快捷理財中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['美孚分行', '九龍美孚新邨第4期美孚廣場1樓106-109號舖'],
#     'city': '九龍',
#     'latitude': '22.335983',
#     'longitude': '114.14140199999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 78803,
#    'is-24-hours': False,
#    'name': '美孚分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['27442991'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['美孚分行自動櫃員機', '九龍美孚新邨第4期美孚廣場1樓106-109號舖'],
#     'city': '九龍',
#     'latitude': '22.335983',
#     'longitude': '114.14140199999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 78794,
#    'is-24-hours': True,
#    'name': '美孚分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['美碩樓流動分行自動櫃員機', '新界沙田安睦街18號碩門邨B座美碩樓'],
#     'city': '新界',
#     'latitude': '22.386273',
#     'longitude': '114.20945800000004',
#     'placeId': '',
#     'postalCode': None},
#    'id': 52447,
#    'is-24-hours': False,
#    'name': '美碩樓流動分行自動櫃員機',
#    'regularHours': [{'closeDay': 5,
#      'closeTime': '11:00 AM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '04:00 PM',
#      'openDay': 5,
#      'openTime': '12:00 PM'}],
#    'services': ['hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['秀茂坪邨流動分行自動櫃員機', '九龍秀茂坪秀茂坪邨秀暉樓'],
#     'city': '九龍',
#     'latitude': '22.317779',
#     'longitude': '114.235087',
#     'placeId': '',
#     'postalCode': None},
#    'id': 52342,
#    'is-24-hours': False,
#    'name': '秀茂坪邨流動分行自動櫃員機',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '11:00 AM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 1,
#      'closeTime': '04:00 PM',
#      'openDay': 1,
#      'openTime': '12:00 PM'}],
#    'services': ['hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['欣安邨流動分行自動櫃員機', '新界馬鞍山欣安邨欣喜樓(恆泰路側)'],
#     'city': '新界',
#     'latitude': '22.41425',
#     'longitude': '114.22588999999994',
#     'placeId': '',
#     'postalCode': None},
#    'id': 52429,
#    'is-24-hours': False,
#    'name': '欣安邨流動分行自動櫃員機',
#    'regularHours': [{'closeDay': 2,
#      'closeTime': '11:00 AM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '04:00 PM',
#      'openDay': 2,
#      'openTime': '12:00 PM'}],
#    'services': ['hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['海麗邨流動分行自動櫃員機', '九龍長沙灣深旺道100號海麗邨海禧樓(海麗商場對面)'],
#     'city': '九龍',
#     'latitude': '22.332494',
#     'longitude': '114.14631800000006',
#     'placeId': '',
#     'postalCode': None},
#    'id': 52435,
#    'is-24-hours': False,
#    'name': '海麗邨流動分行自動櫃員機',
#    'regularHours': [{'closeDay': 3,
#      'closeTime': '11:00 AM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '04:00 PM',
#      'openDay': 3,
#      'openTime': '12:00 PM'}],
#    'services': ['hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['68 彌敦道分行',
#      '九龍尖沙咀彌敦道 66-70 號 金冠大廈地庫, 地下B1號舖及中層'],
#     'city': '九龍',
#     'latitude': '22.297801',
#     'longitude': '114.17245300000002',
#     'placeId': '',
#     'postalCode': None},
#    'id': 53211,
#    'is-24-hours': False,
#    'name': '68 彌敦道分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'safe-deposit-vault',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'international-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['27390777', '27390800'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['祥華邨自動櫃員機', '新界粉嶺新運路38號祥華商場2樓4號舖'],
#     'city': '新界',
#     'latitude': '22.493177',
#     'longitude': '114.14105999999992',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 52452,
#    'is-24-hours': True,
#    'name': '祥華邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['68 彌敦道分行自動櫃員機',
#      '九龍尖沙咀彌敦道66-70號金冠大廈地庫、地下B1號舖'],
#     'city': '九龍',
#     'latitude': '22.297801',
#     'longitude': '114.17245300000002',
#     'placeId': '',
#     'postalCode': None},
#    'id': 52338,
#    'is-24-hours': True,
#    'name': '68 彌敦道分行自動櫃員機',
#    'services': ['24%e5%b0%8f%e6%99%82%e6%b8%af%e5%b9%a3%e5%8f%8a%e4%ba%ba%e6%b0%91%e5%b9%a3%e8%87%aa%e5%8b%95%e6%ab%83%e5%93%a1%e6%a9%9f-%e6%8f%90%e4%be%9b%e6%b8%af%e5%b9%a31000%e5%85%83%e7%8f%be%e9%88%94',
#     'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['落馬洲港鐵站', '新界落馬洲港鐵站310號鋪'],
#     'city': '落馬洲',
#     'latitude': '22.514479',
#     'longitude': '114.065651',
#     'placeId': '',
#     'postalCode': None},
#    'id': 59821,
#    'is-24-hours': True,
#    'name': '落馬洲港鐵站',
#    'services': ['24%e5%b0%8f%e6%99%82%e6%b8%af%e5%b9%a3%e5%8f%8a%e4%ba%ba%e6%b0%91%e5%b9%a3%e8%87%aa%e5%8b%95%e6%ab%83%e5%93%a1%e6%a9%9f-%e6%8f%90%e4%be%9b%e6%b8%af%e5%b9%a31000%e5%85%83%e7%8f%be%e9%88%94'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['尖沙咀 - 企業特快中心', '九龍尖沙咀堪富利士道8號格蘭中心703室'],
#     'city': '九龍',
#     'latitude': '22.2985564',
#     'longitude': '114.17352149999999',
#     'placeId': '',
#     'postalCode': None},
#    'id': 37146,
#    'is-24-hours': False,
#    'name': '尖沙咀 - 企業特快中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:30 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:30 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:30 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:30 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:30 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'}],
#    'services': ['corporate-express-centre'],
#    'status': 'open',
#    'telephone': ['27220681'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['海悅豪園自動櫃員機', ' 新界將軍澳培成路18號海悅豪園商場地下2號自動櫃員機'],
#     'city': '新界',
#     'latitude': '22.314884',
#     'longitude': '114.26566600000001',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23255,
#    'is-24-hours': True,
#    'name': '海悅豪園自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['中環分行自動櫃員機',
#      '香港中環德輔道中26號華懋中心 II 期地下,一樓, 二樓及二十七樓'],
#     'city': '香港',
#     'latitude': '22.28278',
#     'longitude': '114.15707999999995',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23253,
#    'is-24-hours': True,
#    'name': '中環分行自動櫃員機',
#    'services': ['24%e5%b0%8f%e6%99%82%e6%b8%af%e5%b9%a3%e5%8f%8a%e4%ba%ba%e6%b0%91%e5%b9%a3%e8%87%aa%e5%8b%95%e6%ab%83%e5%93%a1%e6%a9%9f-%e6%8f%90%e4%be%9b%e6%b8%af%e5%b9%a31000%e5%85%83%e7%8f%be%e9%88%94',
#     'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['尖沙咀分行自動櫃員機',
#      '九龍尖沙咀彌敦道132號美麗華廣場一期地下G30號鋪及低層地下B117-23號舖'],
#     'city': '九龍',
#     'latitude': '22.301222',
#     'longitude': '114.17212199999994',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23248,
#    'is-24-hours': True,
#    'name': '尖沙咀分行自動櫃員機',
#    'services': ['24%e5%b0%8f%e6%99%82%e6%b8%af%e5%b9%a3%e5%8f%8a%e4%ba%ba%e6%b0%91%e5%b9%a3%e8%87%aa%e5%8b%95%e6%ab%83%e5%93%a1%e6%a9%9f-%e6%8f%90%e4%be%9b%e6%b8%af%e5%b9%a31000%e5%85%83%e7%8f%be%e9%88%94',
#     'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['尖沙咀分行',
#      '香港九龍尖沙咀彌敦道132號美麗華廣場一期地下G30號舖及低層地下B117-23號舖'],
#     'city': ' 九龍',
#     'latitude': '22.301222',
#     'longitude': '114.17212199999994',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23249,
#    'is-24-hours': False,
#    'name': '尖沙咀分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'international-banking-centre',
#     'digital-teller',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['2721 8596', '2366 2959'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['香港灣仔 - 企業特快中心', '軒尼詩道139號中國海外大廈24字樓A室'],
#     'city': '香港',
#     'latitude': '22.2778337',
#     'longitude': '114.17277839999997',
#     'placeId': '',
#     'postalCode': None},
#    'id': 1451,
#    'is-24-hours': False,
#    'name': '香港灣仔 - 企業特快中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:30 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:30 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:30 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:30 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:30 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'}],
#    'services': ['corporate-express-centre'],
#    'status': 'open',
#    'telephone': ['2572 7254'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['香港中環 - 企業特快中心', '德輔道中4-4A號渣打銀行大廈3樓'],
#     'city': '香港',
#     'latitude': '22.280297',
#     'longitude': '114.15905199999997',
#     'placeId': '',
#     'postalCode': None},
#    'id': 1449,
#    'is-24-hours': False,
#    'name': '香港中環 - 企業特快中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:30 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:30 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:30 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:30 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:30 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'}],
#    'services': ['corporate-express-centre'],
#    'status': 'open',
#    'telephone': ['2537 3124'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['香港上環 - 企業特快中心', '德輔道中199號無限極廣場27樓2706室'],
#     'city': '香港',
#     'latitude': '22.286463',
#     'longitude': '114.1536893',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23239,
#    'is-24-hours': False,
#    'name': '香港上環 - 企業特快中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:30 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:30 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:30 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:30 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:30 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'}],
#    'services': ['corporate-express-centre'],
#    'status': 'open',
#    'telephone': ['2854 2089'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['九龍觀塘 - 企業特快中心', '觀塘道388號渣打中心15樓'],
#     'city': '九龍',
#     'latitude': '22.31394',
#     'longitude': '114.22127009999997',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23238,
#    'is-24-hours': False,
#    'name': '九龍觀塘 - 企業特快中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:30 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:30 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:30 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:30 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:30 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'}],
#    'services': ['corporate-express-centre'],
#    'status': 'open',
#    'telephone': ['2282 2514'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['愉翠苑自動櫃員機', ' 新界沙田愉翠苑愉翠商場1樓122號舖對面'],
#     'city': '新界',
#     'latitude': '22.382113',
#     'longitude': '114.20504800000003',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23220,
#    'is-24-hours': True,
#    'name': '愉翠苑自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['科學園自動櫃員機', ' 新界沙田白石角香港科學園1期地下S009號舖'],
#     'city': '新界',
#     'latitude': '22.425498',
#     'longitude': '114.21292700000004',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23221,
#    'is-24-hours': True,
#    'name': '科學園自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['太安樓分行自動櫃員機',
#      '香港筲箕灣筲箕灣道 85-87 號太安樓地下A-B舖及1樓160-161 號舖'],
#     'city': '香港',
#     'latitude': '22.282641',
#     'longitude': '114.22127',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23222,
#    'is-24-hours': True,
#    'name': '太安樓分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm',
#     '%e7%8f%be%e9%87%91%e5%8f%8a%e6%94%af%e7%a5%a8%e5%ad%98%e6%ac%be%e6%a9%9f%e5%8f%aa%e9%99%90%e9%8a%80%e8%a1%8c%e7%87%9f%e6%a5%ad%e6%99%82%e9%96%93'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['大圍分行自動櫃員機', '新界大圍大圍道90號地下及積福街103及105 號地下'],
#     'city': '新界',
#     'latitude': '22.374195',
#     'longitude': '114.178492',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23223,
#    'is-24-hours': True,
#    'name': '大圍分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['沙田廣場分行自動櫃員機',
#      '新界沙田正街 21-27 號 沙田廣場地下8及13-16A 號舖'],
#     'city': '',
#     'latitude': '22.383299',
#     'longitude': '114.18913700000007',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23224,
#    'is-24-hours': True,
#    'name': '沙田廣場分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['美居中心麥當勞自動櫃員機',
#      ' 九龍深水埗元州街213號美居中心 9-19號舖及地下舖 '],
#     'city': ' 九龍',
#     'latitude': '22.334607',
#     'longitude': '114.16029300000002',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23225,
#    'is-24-hours': True,
#    'name': '美居中心麥當勞自動櫃員機',
#    'services': ['mcdonalds-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['欽州街麥當勞自動櫃員機', ' 九龍深水埗欽州街 78-86號地下及閣樓 '],
#     'city': ' 九龍',
#     'latitude': '22.331918',
#     'longitude': '114.16149300000006',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23226,
#    'is-24-hours': True,
#    'name': '欽州街麥當勞自動櫃員機',
#    'services': ['mcdonalds-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['大角咀麥當勞自動櫃員機',
#      ' 九龍大角咀道97-105大同新邨大方樓地下J1,J2號舖'],
#     'city': ' 九龍',
#     'latitude': '22.321272',
#     'longitude': '114.16162199999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23227,
#    'is-24-hours': True,
#    'name': '大角咀麥當勞自動櫃員機',
#    'services': ['mcdonalds-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['土瓜灣麥當勞自動櫃員機', ' 九龍土瓜灣道35-37號及淅江街31號C地下'],
#     'city': ' 九龍',
#     'latitude': '22.315344',
#     'longitude': '114.188627',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23230,
#    'is-24-hours': True,
#    'name': '土瓜灣麥當勞自動櫃員機',
#    'services': ['mcdonalds-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['毓華街麥當勞自動櫃員機', ' 九龍慈雲山毓華街68號萬年戲院大廈地下'],
#     'city': ' 九龍',
#     'latitude': '22.347205',
#     'longitude': '114.20237500000007',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23234,
#    'is-24-hours': True,
#    'name': '毓華街麥當勞自動櫃員機',
#    'services': ['mcdonalds-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['荃灣街市街麥當勞自動櫃員機', ' 新界荃灣街市街10 - 16號地下'],
#     'city': '新界',
#     'latitude': '22.371947',
#     'longitude': '114.11666600000001',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23235,
#    'is-24-hours': True,
#    'name': '荃灣街市街麥當勞自動櫃員機',
#    'services': ['mcdonalds-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['德士古道麥當勞自動櫃員機',
#      ' 新界荃灣德士古道富麗商場1A, 2B, 3A-B, 9A-B & 9C地舖'],
#     'city': '新界',
#     'latitude': '22.368925',
#     'longitude': '114.12213599999995',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23236,
#    'is-24-hours': True,
#    'name': '德士古道麥當勞自動櫃員機',
#    'services': ['mcdonalds-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['港灣豪庭廣場自動櫃員機', ' 九龍大角咀福利街8號港灣豪庭廣場地下G20號舖對面'],
#     'city': ' 九龍',
#     'latitude': '22.324314',
#     'longitude': '114.16059599999994',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23214,
#    'is-24-hours': True,
#    'name': '港灣豪庭廣場自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['西貢分行自動櫃員機', ' 新界西貢灣景道 1,3及5號地下'],
#     'city': '新界',
#     'latitude': '22.381419',
#     'longitude': '114.27136199999995',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23196,
#    'is-24-hours': True,
#    'name': '西貢分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['富昌邨自動櫃員機', '九龍深水埗富昌邨富昌商場一樓3號自動櫃員機3號位置'],
#     'city': ' 九龍',
#     'latitude': '22.327744',
#     'longitude': '114.15470200000004',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23217,
#    'is-24-hours': True,
#    'name': '富昌邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['鰂魚涌分行自動櫃員機',
#      ' 香港鰂魚涌英皇道 1027 號惠安苑地下G6號舖及地下低層LG1號舖'],
#     'city': '香港',
#     'latitude': '22.28516',
#     'longitude': '114.21308099999999',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23197,
#    'is-24-hours': True,
#    'name': '鰂魚涌分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['福榮街自動櫃員機', ' 九龍深水埗福榮街90號地下C舖'],
#     'city': ' 九龍',
#     'latitude': '22.33196',
#     'longitude': '114.16274599999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23218,
#    'is-24-hours': True,
#    'name': '福榮街自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['太子道分行自動櫃員機', ' 九龍太子道西157號別樹華軒地下'],
#     'city': ' 九龍',
#     'latitude': '22.32398',
#     'longitude': '114.16877999999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23198,
#    'is-24-hours': True,
#    'name': '太子道分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['創紀之城2期自動櫃員機', ' 九龍牛頭角觀塘道378號創紀之城2期怡和科技中心1樓'],
#     'city': ' 九龍',
#     'latitude': '22.31453',
#     'longitude': '114.22047999999995',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23199,
#    'is-24-hours': True,
#    'name': '創紀之城2期自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['渣打中心自動櫃員機', ' 九龍牛頭角觀塘道388號創紀之城1期渣打中心地下5A舖'],
#     'city': ' 九龍',
#     'latitude': '22.31394',
#     'longitude': '114.22127',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23200,
#    'is-24-hours': True,
#    'name': '渣打中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['德福花園分行自動櫃員機', ' 九龍九龍灣德福花園德福廣場平台P9-12號舖'],
#     'city': ' 九龍',
#     'latitude': '22.323528',
#     'longitude': '114.212537',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23201,
#    'is-24-hours': True,
#    'name': '德福花園分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['耀安邨自動櫃員機', ' 新界沙田馬鞍山耀安邨耀安商場ATM 1號舖 (近106號舖)'],
#     'city': '新界',
#     'latitude': '22.41887',
#     'longitude': '114.23028999999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23202,
#    'is-24-hours': True,
#    'name': '耀安邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['美孚優先理財中心自動櫃員機',
#      ' 九龍美孚新邨第4期美孚廣場地下G5,G6,G7及G9號舖'],
#     'city': ' 九龍',
#     'latitude': '22.336201',
#     'longitude': '114.14175399999999',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23203,
#    'is-24-hours': True,
#    'name': '美孚優先理財中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['旺角分行自動櫃員機', ' 九龍旺角彌敦道 617-623 號 地下B舖'],
#     'city': ' 九龍',
#     'latitude': '22.317266',
#     'longitude': '114.16970900000001',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23205,
#    'is-24-hours': True,
#    'name': '旺角分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['信德中心3/F自動櫃員機',
#      '香港上環干諾道中168-200號信德中心3樓鄰近電梯L37'],
#     'city': '香港',
#     'latitude': '22.288',
#     'longitude': '114.15165100000002',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23206,
#    'is-24-hours': True,
#    'name': '信德中心3/F自動櫃員機',
#    'services': ['24%e5%b0%8f%e6%99%82%e6%b8%af%e5%b9%a3%e5%8f%8a%e4%ba%ba%e6%b0%91%e5%b9%a3%e8%87%aa%e5%8b%95%e6%ab%83%e5%93%a1%e6%a9%9f-%e6%8f%90%e4%be%9b%e6%b8%af%e5%b9%a31000%e5%85%83%e7%8f%be%e9%88%94'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['藍灣半島自動櫃員機', ' 柴灣小西灣道28號藍灣半島廣場地下A段走廊'],
#     'city': '香港',
#     'latitude': '22.266172',
#     'longitude': '114.25077899999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23207,
#    'is-24-hours': True,
#    'name': '藍灣半島自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['顯徑邨自動櫃員機', ' 新界沙田顯徑邨顯徑商場地下B翼'],
#     'city': '新界',
#     'latitude': '22.36506',
#     'longitude': '114.17389000000003',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23209,
#    'is-24-hours': True,
#    'name': '顯徑邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['石塘咀分行自動櫃員機', '香港石塘咀皇后大道西455-485地下 8-12 號舖'],
#     'city': '香港',
#     'latitude': '22.286215',
#     'longitude': '114.13498600000003',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23210,
#    'is-24-hours': True,
#    'name': '石塘咀分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['太古城中心分行自動櫃員機',
#      ' 香港鰂魚涌太古城太古城道18號太古城中心第2期地下42-43號舖'],
#     'city': '香港',
#     'latitude': '22.285773',
#     'longitude': '114.217264',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23211,
#    'is-24-hours': True,
#    'name': '太古城中心分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['八號花園分行自動櫃員機', ' 新界大埔八號花園地下21號舖'],
#     'city': '新界',
#     'latitude': '22.452513',
#     'longitude': '114.16611899999998',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23212,
#    'is-24-hours': True,
#    'name': '八號花園分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['新蒲崗分行自動櫃員機', ' 九龍新蒲崗大有街31號善美工業大廈地下A 號舖'],
#     'city': ' 九龍',
#     'latitude': '22.336659',
#     'longitude': '114.19802000000004',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23195,
#    'is-24-hours': True,
#    'name': '新蒲崗分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['上水中心分行自動櫃員機', '新界上水智昌路3號上水中心地下1021-1023號舖'],
#     'city': '新界',
#     'latitude': '22.501098',
#     'longitude': '114.13070300000004',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23213,
#    'is-24-hours': True,
#    'name': '上水中心分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['和宜合道分行自動櫃員機',
#      ' 新界葵涌和宜合道 124-128 及 132/ 136 號 利和大廈地下 1-2 號舖'],
#     'city': '新界',
#     'latitude': '22.366991',
#     'longitude': '114.138058',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23179,
#    'is-24-hours': True,
#    'name': '和宜合道分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['啟田邨自動櫃員機', '九龍藍田啟田邨啟田商場新翼地下'],
#     'city': '九龍',
#     'latitude': '22.310456',
#     'longitude': '114.23788200000001',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23180,
#    'is-24-hours': True,
#    'name': '啟田邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港廸士尼樂園 - 香港廸士尼樂園酒店自動櫃員機',
#      ' 香港大嶼山香港廸士尼樂園度假區香港廸士尼樂園酒店'],
#     'city': '新界',
#     'latitude': '22.315548',
#     'longitude': '114.04560600000002',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23181,
#    'is-24-hours': True,
#    'name': '香港廸士尼樂園 - 香港廸士尼樂園酒店自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港廸士尼樂園 - 廸士尼好萊塢酒店 自動櫃員機',
#      ' 香港大嶼山香港廸士尼樂園度假區迪士尼好萊塢酒店'],
#     'city': '新界',
#     'latitude': '22.315501',
#     'longitude': '114.04562299999998',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23182,
#    'is-24-hours': True,
#    'name': '香港廸士尼樂園 - 廸士尼好萊塢酒店 自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港廸士尼樂園 - 廸士尼行政大樓自動櫃員機',
#      ' 香港大嶼山香港廸士尼樂園度假區廸士尼行政大樓 '],
#     'city': '新界',
#     'latitude': '22.315488',
#     'longitude': '114.045614',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23183,
#    'is-24-hours': True,
#    'name': '香港廸士尼樂園 - 廸士尼行政大樓自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港廸士尼樂園 - 售票處自動櫃員機', ' 香港大嶼山香港廸士尼樂園度假區售票處 '],
#     'city': '新界',
#     'latitude': '22.315498',
#     'longitude': '114.04562499999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23184,
#    'is-24-hours': True,
#    'name': '香港廸士尼樂園 - 售票處自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['葵盛西邨自動櫃員機', ' 新界葵涌葵盛西邨葵盛西商場地下20及21號舖側'],
#     'city': '新界',
#     'latitude': '22.360726',
#     'longitude': '114.12230999999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 190,
#    'is-24-hours': True,
#    'name': '葵盛西邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港廸士尼樂園大會堂 自動櫃員機', ' 香港大嶼山香港廸士尼樂園度假區大會堂 '],
#     'city': '新界',
#     'latitude': '22.315479',
#     'longitude': '114.04563000000007',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23185,
#    'is-24-hours': True,
#    'name': '香港廸士尼樂園大會堂 自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['新都會廣場分行自動櫃員機', ' 新界葵芳興芳路 223 號新都會廣場買樓473B號舖'],
#     'city': '新界',
#     'latitude': '22.357362',
#     'longitude': '114.12706600000001',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 191,
#    'is-24-hours': True,
#    'name': '新都會廣場分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['逸東邨自動櫃員機', ' 大嶼山東涌逸東邨逸東商場地下23號舖側'],
#     'city': '新界',
#     'latitude': '22.281713',
#     'longitude': '113.93480499999998',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23186,
#    'is-24-hours': True,
#    'name': '逸東邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['都會商場自動櫃員機', ' 紅磡都會道6號都會商場7樓D區'],
#     'city': ' 九龍',
#     'latitude': '22.302631',
#     'longitude': '114.18364900000006',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 192,
#    'is-24-hours': True,
#    'name': '都會商場自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['羅湖港鐵站自動櫃員機',
#      ' 新界羅湖港鐵羅湖站G/F 車站大堂LOW5 號舖內自動櫃員機機位 LOW ATM 3'],
#     'city': '新界',
#     'latitude': '22.52889',
#     'longitude': '114.11301600000002',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23187,
#    'is-24-hours': True,
#    'name': '羅湖港鐵站自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['黃埔新邨自動櫃員機', ' 九龍紅磡德民街52號黃埔新邨第4期6E及7C1號舖'],
#     'city': ' 九龍',
#     'latitude': '22.305939',
#     'longitude': '114.18778099999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 193,
#    'is-24-hours': True,
#    'name': '黃埔新邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['錦泰商場自動櫃員機', '新界沙田馬鞍山錦泰苑錦泰商場1樓'],
#     'city': '新界',
#     'latitude': '22.408975',
#     'longitude': '114.22178499999995',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23188,
#    'is-24-hours': True,
#    'name': '錦泰商場自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['紅磡廣場分行自動櫃員機',
#      '九龍紅磡馬頭圍道 37-39 號紅磡廣場地下 33-37 舖'],
#     'city': '九龍',
#     'latitude': '22.310148',
#     'longitude': '114.18778999999995',
#     'placeId': '',
#     'postalCode': None},
#    'id': 194,
#    'is-24-hours': True,
#    'name': '紅磡廣場分行自動櫃員機',
#    'services': ['24%e5%b0%8f%e6%99%82%e6%b8%af%e5%b9%a3%e5%8f%8a%e4%ba%ba%e6%b0%91%e5%b9%a3%e8%87%aa%e5%8b%95%e6%ab%83%e5%93%a1%e6%a9%9f-%e6%8f%90%e4%be%9b%e6%b8%af%e5%b9%a31000%e5%85%83%e7%8f%be%e9%88%94',
#     'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['馬鞍山分行自動櫃員機', ' 新界沙田馬鞍山馬鞍山廣場 2 樓 231-234號舖'],
#     'city': '新界',
#     'latitude': '22.425767',
#     'longitude': '114.23223499999995',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23189,
#    'is-24-hours': True,
#    'name': '馬鞍山分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['跑馬地分行自動櫃員機', ' 香港跑馬地景光街16號地下'],
#     'city': '香港',
#     'latitude': '22.269098',
#     'longitude': '114.18494299999998',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 195,
#    'is-24-hours': True,
#    'name': '跑馬地分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['旺角中心分行自動櫃員機', ' 九龍彌敦道688號旺角中心一期地下G30及G31號舖'],
#     'city': '九龍',
#     'latitude': '22.319835',
#     'longitude': '114.16969599999993',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23190,
#    'is-24-hours': True,
#    'name': '旺角中心分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港國際貨櫃碼頭有限公司自動櫃員機',
#      ' 新界葵涌四號貨櫃碼頭香港國際貨櫃碼頭有限公司地下'],
#     'city': '新界',
#     'latitude': '22.339646',
#     'longitude': '114.12567100000001',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 196,
#    'is-24-hours': True,
#    'name': '香港國際貨櫃碼頭有限公司自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['北角中心分行自動櫃員機', ' 香港北角英皇道 278-288 號北角中心地下G2舖'],
#     'city': '香港',
#     'latitude': '22.289844',
#     'longitude': '114.19519200000002',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23191,
#    'is-24-hours': True,
#    'name': '北角中心分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['葵涌分行自動櫃員機', ' 新界葵涌工業街 2-8 號力豐工業大廈地下A舖'],
#     'city': '新界',
#     'latitude': '22.362691',
#     'longitude': '114.13395600000001',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23102,
#    'is-24-hours': True,
#    'name': '葵涌分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['北角港運城分行自動櫃員機', '香港北角英皇道500 號港運城地下003 號舖'],
#     'city': '香港',
#     'latitude': '22.291407',
#     'longitude': '114.20228599999996',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23192,
#    'is-24-hours': True,
#    'name': '北角港運城分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['安蔭邨自動櫃員機', ' 新界葵涌安蔭邨安蔭商場地下'],
#     'city': '新界',
#     'latitude': '22.369477',
#     'longitude': '114.14163699999995',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23103,
#    'is-24-hours': True,
#    'name': '安蔭邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['鯉景灣自動櫃員機', ' 香港西灣河鯉景灣太康街45號D區GD40A號舖'],
#     'city': '香港',
#     'latitude': '22.282474',
#     'longitude': '114.22270300000002',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23194,
#    'is-24-hours': True,
#    'name': '鯉景灣自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['石籬購物中心自動櫃員機', ' 新界葵涌石籬購物中心2期鄰近238號舖'],
#     'city': '新界',
#     'latitude': '22.365629',
#     'longitude': '114.13936799999999',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23178,
#    'is-24-hours': True,
#    'name': '石籬購物中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['海逸坊自動櫃員機', ' 九龍紅磡海逸道8號海逸坊地下高層'],
#     'city': ' 九龍',
#     'latitude': '22.309233',
#     'longitude': '114.19139799999994',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23098,
#    'is-24-hours': True,
#    'name': '海逸坊自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['新翠花園快捷理財中心自動櫃員機', '香港柴灣新翠花園新翠商場地下101號舖'],
#     'city': '香港',
#     'latitude': '22.264079',
#     'longitude': '114.23729400000002',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23164,
#    'is-24-hours': True,
#    'name': '新翠花園快捷理財中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['碧湖花園自動櫃員機', '新界粉嶺一鳴路15號碧湖花園低層地下'],
#     'city': '新界',
#     'latitude': '22.488032',
#     'longitude': '114.14248900000007',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23100,
#    'is-24-hours': True,
#    'name': '碧湖花園自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['長沙灣分行自動櫃員機', ' 九龍荔枝角長沙灣道 828 號地下'],
#     'city': ' 九龍',
#     'latitude': '22.337548',
#     'longitude': '114.14865299999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23165,
#    'is-24-hours': True,
#    'name': '長沙灣分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['葵盛東邨自動櫃員機', ' 新界葵涌葵盛東邨葵盛東商場地下8號舖對面'],
#     'city': '新界',
#     'latitude': '22.364598',
#     'longitude': '114.12709199999995',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23101,
#    'is-24-hours': True,
#    'name': '葵盛東邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['嘉福邨自動櫃員機', ' 新界粉嶺嘉福邨嘉福商場地下2號舖側'],
#     'city': '新界',
#     'latitude': '22.493587',
#     'longitude': '114.135492',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23166,
#    'is-24-hours': True,
#    'name': '嘉福邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['香港迪士尼樂園 - 迪士尼探索家度假酒店自動櫃員機',
#      ' 香港大嶼山香港迪士尼樂園度假區迪士尼探索家度假酒店'],
#     'city': '新界',
#     'latitude': '22.315548',
#     'longitude': '114.04560600000002',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23150,
#    'is-24-hours': True,
#    'name': '香港迪士尼樂園 - 迪士尼探索家度假酒店自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['帝庭軒自動櫃員機', ' 新界粉嶺聯和墟和滿街8號帝庭軒商場1樓'],
#     'city': '新界',
#     'latitude': '22.50056',
#     'longitude': '114.14387899999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23167,
#    'is-24-hours': True,
#    'name': '帝庭軒自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['沙田新城市廣場優先理財中心自動櫃員機',
#      ' 新界沙田新城市廣場第一期2樓 222 & 223 號舖'],
#     'city': '新界',
#     'latitude': '22.38223',
#     'longitude': '114.18833999999993',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23151,
#    'is-24-hours': True,
#    'name': '沙田新城市廣場優先理財中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['火炭分行自動櫃員機',
#      ' 新界沙田火炭山尾街18-24號沙田商業中心1樓3, 5, 10號舖'],
#     'city': '新界',
#     'latitude': '22.39733',
#     'longitude': '114.19343000000003',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23168,
#    'is-24-hours': True,
#    'name': '火炭分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['安定邨自動櫃員機',
#      ' 香港新界屯門屯門鄉事會路2A號安定邨新翼大樓2樓自動櫃員機1號位置'],
#     'city': '香港',
#     'latitude': '22.3869183',
#     'longitude': '113.9780849',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23152,
#    'is-24-hours': True,
#    'name': '安定邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['又一城優先理財服務中心自動櫃員機', ' 九龍九龍塘又一城G08號舖'],
#     'city': ' 九龍',
#     'latitude': '22.337064',
#     'longitude': '114.17486600000007',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23169,
#    'is-24-hours': True,
#    'name': '又一城優先理財服務中心自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['朗屏邨自動櫃員機', ' 香港新界元朗朗屏路1號朗屏邨鏡屏樓第5座閣樓M003A舖'],
#     'city': '新界',
#     'latitude': '22.449877',
#     'longitude': '114.02327000000002',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23153,
#    'is-24-hours': True,
#    'name': '朗屏邨自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['交易廣場分行自動櫃員機', ' 香港中環康樂廣場8號交易廣場富臨閣'],
#     'city': '香港',
#     'latitude': '22.284134',
#     'longitude': '114.15761399999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23154,
#    'is-24-hours': True,
#    'name': '交易廣場分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['樂富中心分行自動櫃員機', ' 九龍樂富聯合道198號樂富廣場第2期地下G201號舖'],
#     'city': ' 九龍',
#     'latitude': '22.337571',
#     'longitude': '114.18769199999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23156,
#    'is-24-hours': True,
#    'name': '樂富中心分行自動櫃員機',
#    'services': ['24hour-hkdrmb-atm', 'cash-and-cheque-deposit-machines'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['北香港優先理財中心 ATM自動櫃員機 ',
#      ' 新界上水龍琛路39號 上水廣場 6樓 601-610 及623A室'],
#     'city': '新界',
#     'latitude': '22.502596',
#     'longitude': '114.12789399999997',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23157,
#    'is-24-hours': False,
#    'name': '北香港優先理財中心 ATM自動櫃員機',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['長沙灣優先理財中心自動櫃員機',
#      ' 九龍長沙灣長沙灣道 833 號長沙灣廣場地下5號舖及中層'],
#     'city': ' 九龍',
#     'latitude': '22.3372',
#     'longitude': '114.15098',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23158,
#    'is-24-hours': False,
#    'name': '長沙灣優先理財中心自動櫃員機',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['大鴻輝(荃灣)中心地下自動櫃員機', '荃灣眾安街55號大鴻輝(荃灣)中心地下'],
#     'city': '新界',
#     'latitude': '22.370143',
#     'longitude': '114.116959',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23159,
#    'is-24-hours': True,
#    'name': '大鴻輝(荃灣)中心地下自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['中環三號碼頭自動櫃員機', ' 香港中環民光街11號中環3號碼頭'],
#     'city': '香港',
#     'latitude': '22.288142',
#     'longitude': '114.15753100000006',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23160,
#    'is-24-hours': True,
#    'name': '中環三號碼頭自動櫃員機',
#    'services': ['24hour-hkdrmb-atm'],
#    'status': 'open',
#    'telephone': [],
#    'types': ['atm']},
#   {'address': {'addressLines': ['國際金融中心二期自動櫃員機', ' 香港中環金融街8號國際金融中心二期地下'],
#     'city': '香港',
#     'latitude': '22.285297',
#     'longitude': '114.15928299999996',
# ...
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['23208111'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['太古城中心分行', '香港太古城太古城道18號太古城中心第2期地下42-43號舖'],
#     'city': '香港',
#     'latitude': '22.285773',
#     'longitude': '114.21725900000001',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23032,
#    'is-24-hours': False,
#    'name': '太古城中心分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['25681153'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['太安樓分行',
#      '香港筲箕灣筲箕灣道 85-87 號太安樓地下A-B舖及1樓160-161 號舖'],
#     'city': '香港',
#     'latitude': '22.282649',
#     'longitude': '114.22127',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23033,
#    'is-24-hours': False,
#    'name': '太安樓分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['25681161'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['北香港優先理財中心',
#      '新界上水龍琛路39號 上水廣場 6樓 601-610及623A室'],
#     'city': '新界',
#     'latitude': '22.502596',
#     'longitude': '114.12789399999906',
#     'placeId': '',
#     'postalCode': None},
#    'id': 30,
#    'is-24-hours': False,
#    'name': '北香港優先理財中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['priority-banking',
#     'priority-banking-centre',
#     'counter-services',
#     'self-service-banking'],
#    'status': 'open',
#    'telephone': ['29181672'],
#    'types': ['priority-banking-centre']},
#   {'address': {'addressLines': ['石塘咀分行', '香港石塘咀皇后大道西455-485號龍暉花園地下 8-12 號舖'],
#     'city': ' 香港',
#     'latitude': '22.286233',
#     'longitude': '114.13497499999994',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23034,
#    'is-24-hours': False,
#    'name': '石塘咀分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['25172122'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['長沙灣優先理財中心', '九龍長沙灣長沙灣道 833 號長沙灣廣場地下5號舖及中層'],
#     'city': '九龍',
#     'latitude': '22.337243',
#     'longitude': '114.14897199999996',
#     'placeId': '',
#     'postalCode': None},
#    'id': 31,
#    'is-24-hours': False,
#    'name': '長沙灣優先理財中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['priority-banking',
#     'priority-banking-centre',
#     'counter-services',
#     'self-service-banking'],
#    'status': 'open',
#    'telephone': ['27441151'],
#    'types': ['priority-banking-centre']},
#   {'address': {'addressLines': ['上水中心分行', '新界上水智昌路3號上水中心地下1021-1023號舖'],
#     'city': ' 新界',
#     'latitude': '22.501098',
#     'longitude': '114.13070300000004',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23035,
#    'is-24-hours': False,
#    'name': '上水中心分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['26397670'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['火炭優先理財中心',
#      '新界火炭山尾街 18-24 號沙田商業中心1樓 5 及 10 號舖'],
#     'city': '新界',
#     'latitude': '22.39733',
#     'longitude': '114.19343000000003',
#     'placeId': '',
#     'postalCode': None},
#    'id': 32,
#    'is-24-hours': False,
#    'name': '火炭優先理財中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['priority-banking',
#     'priority-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['26905962'],
#    'types': ['priority-banking-centre']},
#   {'address': {'addressLines': ['旺角分行', '九龍旺角彌敦道617-623 號地下B舖, 及1樓至2樓'],
#     'city': '九龍',
#     'latitude': '22.317266',
#     'longitude': '114.16970900000001',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23036,
#    'is-24-hours': False,
#    'name': '旺角分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'international-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['27822322', '23845882'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['中環分行', '香港中環德輔道中26號華懋中心 II 期地下,一樓, 二樓及二十七樓'],
#     'city': '香港',
#     'latitude': '22.28278',
#     'longitude': '114.15707999999995',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23020,
#    'is-24-hours': False,
#    'name': '中環分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'international-banking-centre',
#     'digital-teller',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['28778638', '25239285'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['銅鑼灣分行', '香港銅鑼灣怡和街 38-40A 號 怡華大廈地下至2樓'],
#     'city': ' 香港',
#     'latitude': '22.279631',
#     'longitude': '114.185563',
#     'placeId': '',
#     'postalCode': ''},
#    'id': 23017,
#    'is-24-hours': False,
#    'name': '銅鑼灣分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'safe-deposit-vault',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'international-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['25761226', '28810191'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['時代廣場優先理財中心', '香港銅鑼灣羅素街8號3樓及6樓全層'],
#     'city': '香港',
#     'latitude': '22.278747',
#     'longitude': '114.18181200000004',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23022,
#    'is-24-hours': False,
#    'name': '時代廣場優先理財中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['28810393'],
#    'types': ['priority-banking-centre']},
#   {'address': {'addressLines': ['尖沙咀中小企業理財中心', '九龍尖沙咀彌敦道66-70號金冠大廈一樓'],
#     'city': '九龍',
#     'latitude': '22.297801',
#     'longitude': '114.17245300000002',
#     'placeId': '',
#     'postalCode': None},
#    'id': 3,
#    'is-24-hours': False,
#    'name': '尖沙咀中小企業理財中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['business-banking-centre'],
#    'status': 'open',
#    'telephone': ['29862008'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['銅鑼灣中小企業理財中心', '銅鑼灣怡和街38-40A號怡華大廈M樓'],
#     'city': '香港',
#     'latitude': '22.27963',
#     'longitude': '114.18556000000001',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23003,
#    'is-24-hours': False,
#    'name': '銅鑼灣中小企業理財中心',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['business-banking-centre'],
#    'status': 'open',
#    'telephone': ['22826182'],
#    'types': ['branch']},
#   {'address': {'addressLines': ['灣仔修頓分行', '香港灣仔軒尼詩道156-162 號 利榮大樓地下C2舖,1樓及2樓'],
#     'city': '香港',
#     'latitude': '22.277509',
#     'longitude': '114.17358300000001',
#     'placeId': '',
#     'postalCode': None},
#    'id': 23005,
#    'is-24-hours': False,
#    'name': '灣仔修頓分行',
#    'regularHours': [{'closeDay': 1,
#      'closeTime': '05:00 PM',
#      'openDay': 1,
#      'openTime': '09:00 AM'},
#     {'closeDay': 2,
#      'closeTime': '05:00 PM',
#      'openDay': 2,
#      'openTime': '09:00 AM'},
#     {'closeDay': 3,
#      'closeTime': '05:00 PM',
#      'openDay': 3,
#      'openTime': '09:00 AM'},
#     {'closeDay': 4,
#      'closeTime': '05:00 PM',
#      'openDay': 4,
#      'openTime': '09:00 AM'},
#     {'closeDay': 5,
#      'closeTime': '05:00 PM',
#      'openDay': 5,
#      'openTime': '09:00 AM'},
#     {'closeDay': 6,
#      'closeTime': '01:00 PM',
#      'openDay': 6,
#      'openTime': '09:00 AM'}],
#    'services': ['24-hr-express-banking',
#     'business-banking-centre',
#     'personal-banking',
#     'priority-banking',
#     'priority-banking-centre',
#     'counter-services'],
#    'status': 'open',
#    'telephone': ['25276626'],
#    'types': ['branch']}]}

# %%
data['locations'][0]
# Out:
# {'address': {'addressLines': ['立坊自動櫃員機', '荃灣楊屋道118號立坊地下A舖'],
#   'city': '新界',
#   'latitude': '22.366554',
#   'longitude': '114.117808',
#   'placeId': '',
#   'postalCode': None},
#  'id': 225140,
#  'is-24-hours': True,
#  'name': '立坊自動櫃員機',
#  'services': ['24hour-hkdrmb-atm'],
#  'status': 'open',
#  'telephone': [],
#  'types': ['atm']}

# %%
name = []
address = []
phone = []
X = []
Y = []

for i in range(len(data['locations'])):
    n = data['locations'][i]['name']
    a = data['locations'][i]['address']['addressLines']
    p = data['locations'][i]['telephone']
    cy = data['locations'][i]['address']['latitude']
    cx = data['locations'][i]['address']['longitude']
    name.append(n)
    address.append(a)
    phone.append(p)
    X.append(cx)
    Y.append(cy)

# %%
df = pd.DataFrame({'Name':name,'Address':address,'Phone':phone,'Lon':X,'Lat':Y},columns=['Name','Address','Phone','Lon','Lat'])

# %%
df
# Out:
#                 Name                                            Address  \
# 0            立坊自動櫃員機                         [立坊自動櫃員機, 荃灣楊屋道118號立坊地下A舖]
# 1          嘉里中心自動櫃員機                      [香港鰂魚涌英皇道683號嘉里中心2樓 (富嘉閣舖對面)]
# 2      MegaBox 自動櫃員機              [香港九龍灣宏照道38號企業廣場五期Megabox3樓 (307號舖側)]
# 3       迎東邨流動分行自動櫃員機                                      [大嶼山東涌迎東邨迎喜樓]
# 4        迎東邨- 渣打流動分行                                      [大嶼山東涌迎東邨迎喜樓]
# 5         西九龍站快捷理財中心               [九龍尖沙咀柯士甸道西3號香港西九龍站B2抵港大堂WEK B2-2號舖]
# 6    西九龍站快捷理財中心自動櫃員機               [九龍尖沙咀柯士甸道西3號香港西九龍站B2抵港大堂WEK B2-2號舖]
# 7               美孚分行                   [美孚分行, 九龍美孚新邨第4期美孚廣場1樓106-109號舖]
# 8          美孚分行自動櫃員機              [美孚分行自動櫃員機, 九龍美孚新邨第4期美孚廣場1樓106-109號舖]
# 9       美碩樓流動分行自動櫃員機                 [美碩樓流動分行自動櫃員機, 新界沙田安睦街18號碩門邨B座美碩樓]
# 10     秀茂坪邨流動分行自動櫃員機                      [秀茂坪邨流動分行自動櫃員機, 九龍秀茂坪秀茂坪邨秀暉樓]
# 11      欣安邨流動分行自動櫃員機                  [欣安邨流動分行自動櫃員機, 新界馬鞍山欣安邨欣喜樓(恆泰路側)]
# 12      海麗邨流動分行自動櫃員機         [海麗邨流動分行自動櫃員機, 九龍長沙灣深旺道100號海麗邨海禧樓(海麗商場對面)]
# 13          68 彌敦道分行     [68 彌敦道分行, 九龍尖沙咀彌敦道 66-70 號 金冠大廈地庫, 地下B1號舖及中層]
# 14          祥華邨自動櫃員機                    [祥華邨自動櫃員機, 新界粉嶺新運路38號祥華商場2樓4號舖]
# 15     68 彌敦道分行自動櫃員機       [68 彌敦道分行自動櫃員機, 九龍尖沙咀彌敦道66-70號金冠大廈地庫、地下B1號舖]
# 16            落馬洲港鐵站                            [落馬洲港鐵站, 新界落馬洲港鐵站310號鋪]
# 17      尖沙咀 - 企業特快中心               [尖沙咀 - 企業特快中心, 九龍尖沙咀堪富利士道8號格蘭中心703室]
# 18         海悅豪園自動櫃員機           [海悅豪園自動櫃員機,  新界將軍澳培成路18號海悅豪園商場地下2號自動櫃員機]
# 19         中環分行自動櫃員機    [中環分行自動櫃員機, 香港中環德輔道中26號華懋中心 II 期地下,一樓, 二樓及二十七樓]
# 20        尖沙咀分行自動櫃員機  [尖沙咀分行自動櫃員機, 九龍尖沙咀彌敦道132號美麗華廣場一期地下G30號鋪及低層地下B1...
# 21             尖沙咀分行  [尖沙咀分行, 香港九龍尖沙咀彌敦道132號美麗華廣場一期地下G30號舖及低層地下B117-...
# 22     香港灣仔 - 企業特快中心              [香港灣仔 - 企業特快中心, 軒尼詩道139號中國海外大廈24字樓A室]
# 23     香港中環 - 企業特快中心                 [香港中環 - 企業特快中心, 德輔道中4-4A號渣打銀行大廈3樓]
# 24     香港上環 - 企業特快中心             [香港上環 - 企業特快中心, 德輔道中199號無限極廣場27樓2706室]
# 25     九龍觀塘 - 企業特快中心                    [九龍觀塘 - 企業特快中心, 觀塘道388號渣打中心15樓]
# 26          愉翠苑自動櫃員機                  [愉翠苑自動櫃員機,  新界沙田愉翠苑愉翠商場1樓122號舖對面]
# 27          科學園自動櫃員機                [科學園自動櫃員機,  新界沙田白石角香港科學園1期地下S009號舖]
# 28        太安樓分行自動櫃員機  [太安樓分行自動櫃員機, 香港筲箕灣筲箕灣道 85-87 號太安樓地下A-B舖及1樓160-...
# 29         大圍分行自動櫃員機           [大圍分行自動櫃員機, 新界大圍大圍道90號地下及積福街103及105 號地下]
# ..               ...                                                ...
# 195           紅磡廣場分行          [紅磡廣場分行, 九龍紅磡馬頭圍道 37-39 號紅磡廣場地下 33-37 號舖]
# 196             火炭分行                 [火炭分行, 新界火炭山尾街 18-24 號沙田商業中心1樓3號舖]
# 197           黃埔新邨分行           [黃埔新邨分行, 九龍紅磡德民街36-60F 號黃埔新邨第4期6E及7C1號舖]
# 198            九龍城分行                     [九龍城分行, 九龍九龍城福佬村道18 號成龍居地下2A舖]
# 199            長沙灣分行                             [長沙灣分行, 九龍荔枝角長沙灣道828號]
# 200            跑馬地分行                             [跑馬地分行, 香港跑馬地景光街16號地下]
# 201       新翠花園快捷理財中心                  [新翠花園快捷理財中心, 香港柴灣新翠花園新翠商場地下101號舖]
# 202         金鐘優先理財中心         [金鐘優先理財中心, 香港金鐘金鐘道95號統一中心1樓1009A-B及1010號舖]
# 203       紅磡廣場優先理財中心      [紅磡廣場優先理財中心, 九龍紅磡馬頭圍道 37-39 號紅磡廣場地下 45-47 號舖]
# 204        又一城優先理財中心                 [又一城優先理財中心, 九龍九龍塘達之路 80號又一城 G08號舖]
# 205      太古城中心優先理財中心        [太古城中心優先理財中心, 香港太古城太古城道 18號太古城中心第2期地下44 號舖]
# 206    沙田新城市廣場優先理財中心   [沙田新城市廣場優先理財中心, 新界沙田新城市廣場第 一期 2 樓 222 & 223 號 舖]
# 207           沙田廣場分行         [沙田廣場分行, 新界沙田正街 21-27 號 沙田廣場地下8及13-16A 號舖]
# 208             大圍分行                [大圍分行, 新界大圍大圍道90號地下及積福街103及105 號地下]
# 209            太子道分行                     [太子道分行, 九龍太子太子道西157號別樹華軒地下及1樓]
# 210            新蒲崗分行                            [九龍新蒲崗大有街31號善美工業大厦地下Ａ舖]
# 211          太古城中心分行           [太古城中心分行, 香港太古城太古城道18號太古城中心第2期地下42-43號舖]
# 212            太安樓分行   [太安樓分行, 香港筲箕灣筲箕灣道 85-87 號太安樓地下A-B舖及1樓160-161 號舖]
# 213        北香港優先理財中心      [北香港優先理財中心, 新界上水龍琛路39號 上水廣場 6樓 601-610及623A室]
# 214            石塘咀分行          [石塘咀分行, 香港石塘咀皇后大道西455-485號龍暉花園地下 8-12 號舖]
# 215        長沙灣優先理財中心          [長沙灣優先理財中心, 九龍長沙灣長沙灣道 833 號長沙灣廣場地下5號舖及中層]
# 216           上水中心分行               [上水中心分行, 新界上水智昌路3號上水中心地下1021-1023號舖]
# 217         火炭優先理財中心      [火炭優先理財中心, 新界火炭山尾街 18-24 號沙田商業中心1樓 5 及 10 號舖]
# 218             旺角分行               [旺角分行, 九龍旺角彌敦道617-623 號地下B舖, 及1樓至2樓]
# 219             中環分行         [中環分行, 香港中環德輔道中26號華懋中心 II 期地下,一樓, 二樓及二十七樓]
# 220            銅鑼灣分行               [銅鑼灣分行, 香港銅鑼灣怡和街 38-40A 號 怡華大廈地下至2樓]
# 221       時代廣場優先理財中心                    [時代廣場優先理財中心, 香港銅鑼灣羅素街8號3樓及6樓全層]
# 222      尖沙咀中小企業理財中心                [尖沙咀中小企業理財中心, 九龍尖沙咀彌敦道66-70號金冠大廈一樓]
# 223      銅鑼灣中小企業理財中心                 [銅鑼灣中小企業理財中心, 銅鑼灣怡和街38-40A號怡華大廈M樓]
# 224           灣仔修頓分行        [灣仔修頓分行, 香港灣仔軒尼詩道156-162 號 利榮大樓地下C2舖,1樓及2樓]
#
#                       Phone                 Lon         Lat
# 0                        []          114.117808   22.366554
# 1                        []          114.209748   22.290585
# 2                        []          114.208468   22.320141
# 3                        []          113.953446   22.295719
# 4                        []          113.953446   22.295719
# 5                [25410494]          114.165223   22.303805
# 6                        []          114.165223   22.303805
# 7                [27442991]  114.14140199999997   22.335983
# 8                        []  114.14140199999997   22.335983
# 9                        []  114.20945800000004   22.386273
# 10                       []          114.235087   22.317779
# 11                       []  114.22588999999994    22.41425
# 12                       []  114.14631800000006   22.332494
# 13     [27390777, 27390800]  114.17245300000002   22.297801
# 14                       []  114.14105999999992   22.493177
# 15                       []  114.17245300000002   22.297801
# 16                       []          114.065651   22.514479
# 17               [27220681]  114.17352149999999  22.2985564
# 18                       []  114.26566600000001   22.314884
# 19                       []  114.15707999999995    22.28278
# 20                       []  114.17212199999994   22.301222
# 21   [2721 8596, 2366 2959]  114.17212199999994   22.301222
# 22              [2572 7254]  114.17277839999997  22.2778337
# 23              [2537 3124]  114.15905199999997   22.280297
# 24              [2854 2089]         114.1536893   22.286463
# 25              [2282 2514]  114.22127009999997    22.31394
# 26                       []  114.20504800000003   22.382113
# 27                       []  114.21292700000004   22.425498
# 28                       []           114.22127   22.282641
# 29                       []          114.178492   22.374195
# ..                      ...                 ...         ...
# 195              [27644121]  114.18777799999998   22.310169
# 196              [26932923]  114.19343000000003    22.39733
# 197              [23334102]          114.187768   22.305931
# 198              [23837171]           114.18768    22.32841
# 199              [27444116]  114.14865299999997   22.337548
# 200              [28327073]  114.18494299999998   22.269098
# 201              [28978418]  114.23729400000002   22.264079
# 202              [25291284]  114.16526599999997   22.278362
# 203              [23568066]  114.18761799999993   22.309867
# 204              [22657212]  114.17488700000001   22.337121
# 205              [25693577]  114.21701200000007   22.286739
# 206              [26984223]  114.18833999999993    22.38223
# 207              [26810982]  114.18913700000007   22.383299
# 208              [26032194]          114.178492   22.374195
# 209              [23802308]  114.16877999999997    22.32398
# 210              [23208111]  114.19802000000004   22.336659
# 211              [25681153]  114.21725900000001   22.285773
# 212              [25681161]           114.22127   22.282649
# 213              [29181672]  114.12789399999906   22.502596
# 214              [25172122]  114.13497499999994   22.286233
# 215              [27441151]  114.14897199999996   22.337243
# 216              [26397670]  114.13070300000004   22.501098
# 217              [26905962]  114.19343000000003    22.39733
# 218    [27822322, 23845882]  114.16970900000001   22.317266
# 219    [28778638, 25239285]  114.15707999999995    22.28278
# 220    [25761226, 28810191]          114.185563   22.279631
# 221              [28810393]  114.18181200000004   22.278747
# 222              [29862008]  114.17245300000002   22.297801
# 223              [22826182]  114.18556000000001    22.27963
# 224              [25276626]  114.17358300000001   22.277509
#
# [225 rows x 5 columns]

# %%
df.to_excel('C:/Users/chenyit/Downloads/ATM_SC_HKG_CHN.xlsx')
